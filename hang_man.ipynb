# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidra-Noman/assignment4_python/blob/main/hang_man.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
stages = ['''
    --------
    |      |
    |      |
    |      |
    |      |
    |      |
    --------
    ''', '''
    --------
    |      |
    |      O
    |
    |
    |
    |
    --------
    ''',
    '''
    --------
    |      |
    |      O
    |      |
    |
    |
    |
    --------
    ''',
    '''
    --------
    |      |
    |      O
    |     /|
    |
    |
    |
    --------
    ''',
    '''
    --------
    |      |
    |      O
    |     /|\\
    |
    |
    |
    --------
    ''',
    '''
    --------
    |      |
    |      O
    |     /|\\
    |     /
    |
    |
    --------
    ''',
    '''
    --------
    |      |
    |      O
    |     /|\\
    |     / \\
    |
    |
    --------
    ''']
words = ['apple', 'banana', 'orange', 'mango', 'grapes','melon','guava','pear', 'cherry'] # This line was indented, causing the error. Removed the extra indentation.
chosen_word = random.choice(words)
word_display = ['_' for _ in chosen_word]
guess_letters = []
lives = len(stages)-1
print("Welcome to Hangman Game!")
print("Guess the word")

while True:
    print(' '.join(word_display))
    guess = input("Guess a letter: ").lower()

    if not guess.isalpha() or len(guess) != 1:
        print("Invalid input. Please enter a valid letter.\n")
        continue

    if guess in guess_letters:
        print("You already guessed that letter. Try again.\n")
        continue

    guess_letters.append(guess)
    if guess in chosen_word:
       print("Correct guess!\n")
       for index, letter in enumerate(chosen_word):
            if letter == guess:
                word_display[index] = guess
    else:
        print(f"Sorry {guess} is not in the words")
        print(stages[len(stages) - lives -1])
        lives -= 1
        print(f"You have {lives} lives left.\n")
        if lives == 0:
          print(stages[lives])
          print(f"You lose! The word was '{chosen_word}'.")
          break
# Out:
# Welcome to Hangman Game!
# Guess the word
# _ _ _ _ _
# Guess a letter: n
# Correct guess!
#
# _ _ _ _ n
# Guess a letter: o
# Correct guess!
#
# _ _ _ o n
# Guess a letter: p
# Sorry p is not in the words
#
#     --------
#     |      |
#     |      |
#     |      |
#     |      |
#     |      |
#     --------
#
# You have 5 lives left.
#
# _ _ _ o n
# Guess a letter: s
# Sorry s is not in the words
#
#     --------
#     |      |
#     |      O
#     |
#     |
#     |
#     |
#     --------
#
# You have 4 lives left.
#
# _ _ _ o n
# Guess a letter: d
# Sorry d is not in the words
#
#     --------
#     |      |
#     |      O
#     |      |
#     |
#     |
#     |
#     --------
#
# You have 3 lives left.
#
# _ _ _ o n
# Guess a letter: f
# Sorry f is not in the words
#
#     --------
#     |      |
#     |      O
#     |     /|
#     |
#     |
#     |
#     --------
#
# You have 2 lives left.
#
# _ _ _ o n
# Guess a letter: s
# You already guessed that letter. Try again.
#
# ...
